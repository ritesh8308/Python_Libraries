# %% [markdown]
# # Assignment_01 :
# Create a plot comparing Kohli, Rohit Sharma, and Sehwag across 10 years of hypothetical runs.
#
# ## Use:
#
# * Labels
# * Legends
# * Colors
# * Line styles
# * One custom style

# %% [markdown]
# ## 01. Importing required libraries:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 02. Applying a custom style:

# %%
sns.set_style("whitegrid")  # clean background with gridlines

# %% [markdown]
# ## 03. Defining plot data:

# %%
# 📅 Define years and hypothetical run data
years = list(range(2015, 2025))
kohli_runs = [850, 900, 870, 920, 880, 910, 890, 940, 930, 950]
rohit_runs = [780, 820, 800, 860, 840, 870, 860, 880, 890, 910]
sehwag_runs = [700, 750, 720, 760, 740, 780, 770, 790, 800, 820]

# %% [markdown]
# ## 04. Creating the plot - Hypothetical Runs Comparison (2015-2024):

# %%
# 📈 Create the plot
plt.figure(figsize=(10, 6))

# %% [markdown]
# ## 05. Plotting each players plot with distinct styles:

# %% [markdown]
# ## 06. Adding Labels & Titles:

# %% [markdown]
# ## 07. Adding legend to my plot:

# %%
plt.plot(years, kohli_runs, label='Virat Kohli', color='blue', linestyle='-')
plt.plot(years, rohit_runs, label='Rohit Sharma', color='green', linestyle='--')
plt.plot(years, sehwag_runs, label='Virender Sehwag', color='red', linestyle='-.')


plt.xlabel('Year')
plt.ylabel('Runs Scored')
plt.title('Hypothetical Runs Comparison (2015-2024)')


# 📌 Add legend
plt.legend()


# 📐 Optional: Add grid and tighter layout
plt.grid(True)
plt.tight_layout()

# 📤 Show the plot
#plt.show()
